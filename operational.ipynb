# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/colab+git
# %pwd
# !git add -A
# Out:
# /content/gdrive/My Drive/colab+git

# %%
# !git add -A

# %%
# !git config --global user.name "porouspaper"
# !git config --global user.email "officialgenet@gmail.com"

# %%
# !git commit -m "fixed deg-to-radian conversion"
# Out:
# [master 6e23944] fixed deg-to-radian conversion
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite master-training.ipynb (97%)
#  rewrite operational.ipynb (93%)

# %%
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 899 bytes | 449.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/porouspaper/svo-experiments.git
#    dd738c9..6e23944  master -> master

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
