# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/colab+git
# %pwd
# !git add -A
# Out:
# /content/gdrive/My Drive/colab+git

# %%
# !git add -A

# %%
# !git config --global user.name "porouspaper"
# !git config --global user.email "officialgenet@gmail.com"

# %%
# !git commit -m "include data"
# Out:
# [master f06fc6e] include data
#  6 files changed, 306 insertions(+), 2 deletions(-)
#  create mode 100644 fixed_data/svo-270-1/coop_graph.csv
#  create mode 100644 fixed_data/svo-270-1/defect_graph.csv
#  create mode 100644 fixed_data/svo-270-1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-270-1/self_graph.csv
#  rewrite master-training.ipynb (98%)
#  rewrite operational.ipynb (62%)

# %%
# !git push
# Out:
# Counting objects: 15, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (15/15), 3.29 MiB | 5.82 MiB/s, done.
# Total 15 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 1 local object.
# To https://github.com/porouspaper/svo-experiments.git
#    6e23944..f06fc6e  master -> master

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
