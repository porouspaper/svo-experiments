# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/My Drive/colab+git
# %pwd
# !git add -A
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/colab+git'
# /content/gdrive/My Drive/colab+git

# %%
# !git config --global user.name "porouspaper"
# !git config --global user.email "officialgenet@gmail.com"

# %%
# !git commit -m "updated master-training to eval with boxplots"
# Out:
# [master 3284232] updated master-training to eval with boxplots
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite master-training.ipynb (98%)
#  rewrite operational.ipynb (72%)

# %%
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 10.81 KiB | 1.54 MiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/porouspaper/svo-experiments.git
#    dabb124..3284232  master -> master

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
