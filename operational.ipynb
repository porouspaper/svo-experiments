# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/colab+git
# %pwd
# !git add -A
# Out:
# /content/gdrive/My Drive/colab+git

# %%
# !git config --global user.name "porouspaper"
# !git config --global user.email "officialgenet@gmail.com"

# %%
# !git commit -m "updated master-training"
# Out:
# [master e0dbb18] updated master-training
#  3 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite master-training.ipynb (97%)
#  rewrite operational.ipynb (98%)
#  create mode 100644 svo-0-test-cp/svo-0-test-cp.zip

# %%
# !git push
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 914.14 KiB | 17.92 MiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/porouspaper/svo-experiments.git
#    aa4048c..e0dbb18  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
