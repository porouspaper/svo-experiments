# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/colab+git
# %pwd
# Out:
# /content/gdrive/My Drive/colab+git
# '/content/gdrive/My Drive/colab+git'

# %%
# !git pull
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/porouspaper/svo-experiments
#    93cd199..b24466c  master     -> origin/master
# Updating 93cd199..b24466c
# Fast-forward
#  local_unity.ipynb | 2416 +++++++++++++++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 2416 insertions(+)
#  create mode 100644 local_unity.ipynb

# %%
# !git add -A

# %%
# !git config --global user.name "porouspaper"
# !git config --global user.email "officialgenet@gmail.com"

# %%
# !git commit -m "added many policies"
# Out:
# [master e25e820] added many policies
#  73 files changed, 3631 insertions(+), 406 deletions(-)
#  rewrite fixed_data/svo-000-1-pgg1/coop_graph.csv (99%)
#  rewrite fixed_data/svo-000-1-pgg1/defect_graph.csv (98%)
#  rewrite fixed_data/svo-000-1-pgg1/self_graph.csv (100%)
#  rewrite fixed_data/svo-000-1-pgg1/tft_graph.csv (99%)
#  create mode 100644 fixed_data/svo-045-1-pgg1/coop_graph.csv
#  create mode 100644 fixed_data/svo-045-1-pgg1/defect_graph.csv
#  create mode 100644 fixed_data/svo-045-1-pgg1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-045-1-pgg1/self_graph.csv
#  create mode 100644 fixed_data/svo-045-1-pgg1/tft_graph.csv
#  create mode 100644 fixed_data/svo-090-1-pgg1/coop_graph.csv
#  create mode 100644 fixed_data/svo-090-1-pgg1/defect_graph.csv
#  create mode 100644 fixed_data/svo-090-1-pgg1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-090-1-pgg1/self_graph.csv
#  create mode 100644 fixed_data/svo-090-1-pgg1/tft_graph.csv
#  create mode 100644 fixed_data/svo-135-1-pgg1/coop_graph.csv
#  create mode 100644 fixed_data/svo-135-1-pgg1/defect_graph.csv
#  create mode 100644 fixed_data/svo-135-1-pgg1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-135-1-pgg1/self_graph.csv
#  create mode 100644 fixed_data/svo-135-1-pgg1/tft_graph.csv
#  create mode 100644 fixed_data/svo-180-1-pgg1/coop_graph.csv
#  create mode 100644 fixed_data/svo-180-1-pgg1/defect_graph.csv
#  create mode 100644 fixed_data/svo-180-1-pgg1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-180-1-pgg1/self_graph.csv
#  create mode 100644 fixed_data/svo-180-1-pgg1/tft_graph.csv
#  create mode 100644 fixed_data/svo-225-1-pgg1/coop_graph.csv
#  create mode 100644 fixed_data/svo-225-1-pgg1/defect_graph.csv
#  create mode 100644 fixed_data/svo-225-1-pgg1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-225-1-pgg1/self_graph.csv
#  create mode 100644 fixed_data/svo-225-1-pgg1/tft_graph.csv
#  create mode 100644 fixed_data/svo-270-1-pgg1/coop_graph.csv
#  create mode 100644 fixed_data/svo-270-1-pgg1/defect_graph.csv
#  create mode 100644 fixed_data/svo-270-1-pgg1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-270-1-pgg1/self_graph.csv
#  create mode 100644 fixed_data/svo-270-1-pgg1/tft_graph.csv
#  create mode 100644 fixed_data/svo-315-1-pgg1/coop_graph.csv
#  create mode 100644 fixed_data/svo-315-1-pgg1/defect_graph.csv
#  create mode 100644 fixed_data/svo-315-1-pgg1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-315-1-pgg1/self_graph.csv
#  create mode 100644 fixed_data/svo-315-1-pgg1/tft_graph.csv
#  rewrite master-training.ipynb (93%)
#  create mode 100644 meta_policy.ipynb
#  rewrite operational.ipynb (73%)
#  delete mode 100644 svo-0-test-cp/svo-0-test-cp.zip
#  delete mode 100644 svo-0-test2-cp/svo-0-test2-cp.zip
#  create mode 100644 svo-000-1-pgg1-cp/p/svo-000-1-pgg1-p.zip
#  create mode 100644 svo-000-1-pgg1-cp/p/svo-000-1-pgg1-p/collect_data_spec.pbtxt
#  create mode 100644 svo-000-1-pgg1-cp/p/svo-000-1-pgg1-p/saved_model.pb
#  create mode 100644 svo-000-1-pgg1-cp/p/svo-000-1-pgg1-p/variables/variables.data-00000-of-00001
#  create mode 100644 svo-000-1-pgg1-cp/p/svo-000-1-pgg1-p/variables/variables.index
#  create mode 100644 svo-045-1-pgg1-cp/p/svo-045-1-pgg1-p.zip
#  create mode 100644 svo-045-1-pgg1-cp/p/svo-045-1-pgg1-p/collect_data_spec.pbtxt
#  create mode 100644 svo-045-1-pgg1-cp/p/svo-045-1-pgg1-p/saved_model.pb
#  create mode 100644 svo-045-1-pgg1-cp/p/svo-045-1-pgg1-p/variables/variables.data-00000-of-00001
#  create mode 100644 svo-045-1-pgg1-cp/p/svo-045-1-pgg1-p/variables/variables.index
#  create mode 100644 svo-045-1-pgg1-cp/svo-045-1-pgg1-cp.zip
#  create mode 100644 svo-090-1-pgg1-cp/p/svo-090-1-pgg1-p.zip
#  create mode 100644 svo-090-1-pgg1-cp/p/svo-090-1-pgg1-p/collect_data_spec.pbtxt
#  create mode 100644 svo-090-1-pgg1-cp/p/svo-090-1-pgg1-p/saved_model.pb
#  create mode 100644 svo-090-1-pgg1-cp/p/svo-090-1-pgg1-p/variables/variables.data-00000-of-00001
#  create mode 100644 svo-090-1-pgg1-cp/p/svo-090-1-pgg1-p/variables/variables.index
#  create mode 100644 svo-090-1-pgg1-cp/svo-090-1-pgg1-cp.zip
#  create mode 100644 svo-135-1-pgg1-cp/p/svo-135-1-pgg1-p.zip
#  create mode 100644 svo-135-1-pgg1-cp/p/svo-135-1-pgg1-p/collect_data_spec.pbtxt
#  create mode 100644 svo-135-1-pgg1-cp/p/svo-135-1-pgg1-p/saved_model.pb
#  create mode 100644 svo-135-1-pgg1-cp/p/svo-135-1-pgg1-p/variables/variables.data-00000-of-00001
#  create mode 100644 svo-135-1-pgg1-cp/p/svo-135-1-pgg1-p/variables/variables.index
#  create mode 100644 svo-135-1-pgg1-cp/svo-135-1-pgg1-cp.zip
#  create mode 100644 svo-180-1-pgg1-cp/svo-180-1-pgg1-cp.zip
#  create mode 100644 svo-225-1-pgg1-cp/svo-225-1-pgg1-cp.zip
#  delete mode 100644 svo-270-1-cp/svo-270-1-cp.zip
#  create mode 100644 svo-270-1-pgg1-cp/svo-270-1-pgg1-cp.zip
#  create mode 100644 svo-315-1-pgg1-cp/svo-315-1-pgg1-cp.zip

# %%
# !git push
# Out:
# Counting objects: 97, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (92/92), done.
# Writing objects: 100% (97/97), 12.08 MiB | 7.71 MiB/s, done.
# Total 97 (delta 7), reused 0 (delta 0)
# remote: Resolving deltas: 100% (7/7), completed with 1 local object.
# To https://github.com/porouspaper/svo-experiments.git
#    b24466c..e25e820  master -> master

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
