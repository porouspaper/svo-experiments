# %%
from google.colab import drive
from os.path import join

ROOT = '/content/gdrive'     # default for the drive
PROJ = 'My Drive/colab+git'       # path to your project on Drive

GIT_USERNAME = "porouspaper" # replace with yours
GIT_TOKEN = "e5ffbe3b9e85decb81878346f7b2ced0c7b58bb5"           # definitely replace with yours
GIT_REPOSITORY = "svo-experiments"      # ...nah


drive.mount(ROOT)           # we mount the drive at /content/drive

PROJECT_PATH = join(ROOT, PROJ)
GIT_PATH = "https://e5ffbe3b9e85decb81878346f7b2ced0c7b58bb5@github.com/porouspaper/svo-experiments.git"
# !mkdir /temp
# !mkdir /temp/home
# !cd /temp/home
# !git clone "https://e5ffbe3b9e85decb81878346f7b2ced0c7b58bb5@github.com/porouspaper/svo-experiments.git"
# !mv /temp/home "gdrive/My Drive/colab+git"
# !rm -rf /temp
#!rsync -aP --exclude=data/ "./drive/My Drive/colab+git"/*  ./
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Cloning into 'svo-experiments'...
# ...

# %%
# !cp -r ./home "gdrive/My Drive/colab+git"
# Out:
# cp: cannot stat './home': No such file or directory

# %%
# !cd gdrive/My Drive/colab+git
# Out:
# /bin/bash: line 0: cd: too many arguments
# Reinitialized existing Git repository in /content/.git/
# fatal: pathspec 'README.md' did not match any files
# On branch master
#
# Initial commit
#
# Untracked files:
# 	.config/
# 	gdrive/
# 	sample_data/
#
# nothing added to commit but untracked files present
# fatal: remote origin already exists.
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/porouspaper/svo-experiments.git'
# ^C
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/porouspaper/svo-experiments.git'

# %%
# %pwd
# Out:
# /content/gdrive/My Drive/colab+git
# '/content/gdrive/My Drive/colab+git'

# %%
# !git init
# !git add -A
# !git commit -m "first commit"
# !git remote add origin https://github.com/porouspaper/svo-experiments.git
# !git push -u origin master
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/colab+git/.git/
# [master (root-commit) 72f57c0] first commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 master-training.ipynb
#  create mode 100644 operational.ipynb
# fatal: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote add origin https://github.com/porouspaper/svo-experiments.git
# !git push -u origin master
# Out:
# fatal: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote remove origin

# %%
# !git remote add origin https://{u}:{p}!@github.com/porouspaper/svo-experiments.git

# %%
# %cd
