# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/colab+git
# %pwd
# Out:
# /content/gdrive/My Drive/colab+git
# '/content/gdrive/My Drive/colab+git'

# %%
# !git pull
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/porouspaper/svo-experiments
#    93cd199..b24466c  master     -> origin/master
# Updating 93cd199..b24466c
# Fast-forward
#  local_unity.ipynb | 2416 +++++++++++++++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 2416 insertions(+)
#  create mode 100644 local_unity.ipynb

# %%
# !git add -A

# %%
# !git config --global user.name "porouspaper"
# !git config --global user.email "officialgenet@gmail.com"

# %%
# !git commit -m "fixed some bugs"
# Out:
# [master 93cd199] fixed some bugs
#  12 files changed, 472 insertions(+), 25 deletions(-)
#  rewrite __pycache__/pgg.cpython-36.pyc (79%)
#  create mode 100644 __pycache__/pgg_add.cpython-36.pyc
#  create mode 100644 fixed_data/svo-000-1-pgg1/coop_graph.csv
#  create mode 100644 fixed_data/svo-000-1-pgg1/defect_graph.csv
#  create mode 100644 fixed_data/svo-000-1-pgg1/fixed_game_returns.csv
#  create mode 100644 fixed_data/svo-000-1-pgg1/self_graph.csv
#  create mode 100644 fixed_data/svo-000-1-pgg1/tft_graph.csv
#  rewrite master-training.ipynb (97%)
#  rewrite operational.ipynb (67%)
#  create mode 100644 svo-000-1-pgg1-cp/svo-000-1-pgg1-cp.zip

# %%
# !git push
# Out:
# Counting objects: 17, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (17/17), 2.00 MiB | 5.90 MiB/s, done.
# Total 17 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 4 local objects.
# To https://github.com/porouspaper/svo-experiments.git
#    f06fc6e..93cd199  master -> master

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
