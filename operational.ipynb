# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/colab+git
# %pwd
# !git add -A
# Out:
# /content/gdrive/My Drive/colab+git

# %%
# !git config --global user.name "porouspaper"
# !git config --global user.email "officialgenet@gmail.com"

# %%
# !git commit -m "updated master-training to save"
# Out:
# [master d026727] updated master-training to save
#  6 files changed, 183 insertions(+), 2 deletions(-)
#  create mode 100644 __pycache__/pgg.cpython-36.pyc
#  rewrite master-training.ipynb (98%)
#  rewrite operational.ipynb (97%)
#  create mode 100644 pgg.py
#  create mode 100644 pgg_add.py
#  create mode 100644 svo-0-test2-cp/svo-0-test2-cp.zip

# %%
# !git push
# Out:
# Counting objects: 10, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (10/10), 1021.85 KiB | 15.25 MiB/s, done.
# Total 10 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/porouspaper/svo-experiments.git
#    e0dbb18..d026727  master -> master

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
